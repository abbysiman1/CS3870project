# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

# %%
flight_data  = pd.read_csv('satisfaction_2015.csv')

# %%
flight_data.head()
# Out:
#        id satisfaction_v2  Gender      Customer Type  Age   Type of Travel  \
# 0  117135       satisfied    Male  disloyal Customer   56  Personal Travel
# 1   72091       satisfied    Male  disloyal Customer   49  Personal Travel
# 2   29663       satisfied    Male  disloyal Customer   55  Personal Travel
# 3   81849       satisfied  Female  disloyal Customer   36  Personal Travel
# 4   83693       satisfied    Male  disloyal Customer   55  Personal Travel
#
#   Class  Flight Distance  Inflight wifi service  \
# 0   Eco              369                      0
# 1   Eco             2486                      0
# 2   Eco             1448                      0
# 3   Eco             1501                      0
# 4   Eco              577                      0
#
#    Departure/Arrival time convenient  ...  Seat comfort  \
# 0                                  2  ...             3
# 1                                  2  ...             3
# ...

# %%
flight_data.shape
# Out:
# (129880, 24)

# %%
missing_values_per_column = flight_data.isna().sum()
missing_values_per_column
# Out:
# id                                   0
# satisfaction_v2                      0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# dtype: int64

# %%
# Replacing the NA values of a column with the average of that column
average_column_arrival_delay = flight_data['Arrival Delay in Minutes'].mean()
average_column_arrival_delay
# Replace NaN values in column 'A' with the average of column 'A'
flight_data['Arrival Delay in Minutes'] = flight_data['Arrival Delay in Minutes'].fillna(average_column_arrival_delay)
flight_data.isna().sum()
# Out:
# id                                   0
# satisfaction_v2                      0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# dtype: int64

# %%
for column in flight_data.columns:
    unique_values = flight_data[column].unique()
    print(f"Unique values in column '{column}': {unique_values}")
# Out:
# Unique values in column 'id': [117135  72091  29663 ...  50316  22333  10198]
# Unique values in column 'satisfaction_v2': ['satisfied' 'neutral or dissatisfied']
# Unique values in column 'Gender': ['Male' 'Female']
# Unique values in column 'Customer Type': ['disloyal Customer' 'Loyal Customer']
# Unique values in column 'Age': [56 49 55 36 15 51 26 37 65 18 22 40 14 45 53 35 57 25 10 60 17 68 28 47
#  52 34 13 50 64 39 70  8 32 21 67 62 69 63 12 59 27 20 61 30 66 46 54 38
#  11  7 24 33  9 23 31 58 19 42 16 29 43 48 44 41 72 71 80 77 85 78 75 79
#  74 73 76]
# Unique values in column 'Type of Travel': ['Personal Travel' 'Business travel']
# Unique values in column 'Class': ['Eco' 'Business' 'Eco Plus']
# Unique values in column 'Flight Distance': [ 369 2486 1448 ...  681 3763 3564]
# Unique values in column 'Inflight wifi service': [0 1 2 3 4 5]
# Unique values in column 'Departure/Arrival time convenient': [2 3 4 5 0 1]
# ...

# %%
flight_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 129880 non-null  int64
#  1   satisfaction_v2                    129880 non-null  object
#  2   Gender                             129880 non-null  object
#  3   Customer Type                      129880 non-null  object
#  4   Age                                129880 non-null  int64
#  5   Type of Travel                     129880 non-null  object
#  6   Class                              129880 non-null  object
#  7   Flight Distance                    129880 non-null  int64
#  8   Inflight wifi service              129880 non-null  int64
#  9   Departure/Arrival time convenient  129880 non-null  int64
#  10  Ease of Online booking             129880 non-null  int64
# ...
